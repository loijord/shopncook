# %%
from IPython.display import Markdown, display
with open('hunt.md', 'r', encoding='utf-8') as f:
    display(Markdown(f.read()))
# Out:
# ## Aviečių uogienė
# |    | shop   | image                                                                                                                                                                                                                                                                           | title                                                                                                                                                                                                                                                | price                                                        | price_per                                                          | off    |   weight | date       | valid_until   |
# ...
