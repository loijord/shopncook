# %%
from items import candidates
import pandas as pd
import os
from shopscraping import scrape, get_view, balance_units

def track_item(item, offline=True, sorter=None):
    try:
        candidates
    except NameError:
        from items import candidates
        
    if not(offline):
        print(f'Tracking urls of item = {item.upper()} ...', end=' ')
        
    df = scrape(candidates[item], offline=offline, sorter=sorter)
    df = balance_units(df)
    
    if not(offline):
        print('Done')
        
    if sorter: 
        df = df.sort_values(**sorter)
    return df

def collect_catalogue(items=[], offline=False, balance_weights=True,
                      sorter={'by':['comparative_unit_discount_price', 'shop', 'discount'],
                              'ascending': [True, True, False]}):
    
    '''Return dictionary of scrape results for multiple items 
    Offline parameter is passed into scrape method 
    Input: list of items
    Output: dict
    ''' 
    
    try:
        candidates
    except NameError:
        from items import candidates
        
    item_dfs = dict()
    present_items = [item for item in items if item in candidates]
    missing_items = [item for item in items if item not in candidates]
    
    if missing_items:
        print('Please add urls for items:', missing_items)

    for item in present_items:
        item_dfs[item] = track_item(item, offline=offline, sorter=sorter)
        
    return item_dfs

fridge_dir, fridge_file = 'fridge', 'fridge.csv'
fridge_file_path = os.path.join(fridge_dir, fridge_file)

if fridge_file in os.listdir(fridge_dir):
    df = pd.read_csv(fridge_file_path)
    df = df.sort_values(by=['own', 'hunt', 'asap', 'items'], ascending=[True, False, False, True]).reset_index(drop=True)
    
    items_onwatch = sorted(candidates.keys())
    items_own = df['items'].loc[df['own']==1].tolist()
    items_hunt = df['items'].loc[df['hunt']==1].tolist()
    items_asap = df['items'].loc[df['asap']==1].tolist()
    
    print(f'onwatch:', items_onwatch, end='\n\n')
    print(f'own:', items_own, end='\n\n')
    print(f'hunt:', items_hunt, end='\n\n')
    print(f'asap:', items_asap, end='\n\n')

else:
    items_onwatch = sorted(candidates.keys())
    df = pd.DataFrame(dict(items=items_onwatch, 
                           own=[0 for n in items], 
                           hunt=[0 for n in items], 
                           asap=[0 for n in items]))
    df.to_csv(fridge_file_path, index=False)
# Out:
# onwatch: ['Avietės', 'Aviečių uogienė', 'Avižų gėrimas', 'Bananai', 'Bulvės', 'Burokėliai', 'Druska', 'Džiovinti krapai', 'Grietinė', 'Imbieras', 'Karis', 'Kefyras', 'Kiaušiniai', 'Kokosų gėrimas', 'Kopūstai', 'Laurų lapai', 'Maltos aitriosios paprikos', 'Morkos', 'Paprikos', 'Pienas UAT', 'Pomidorų pasta', 'Rausvieji svogūnai', 'Ridikėliai', 'Skumbrė', 'Sviestas', 'Sviestinis moliūgas', 'Svogūnai', 'Svogūnų laiškai', 'Trumpavaisiai agurkai', 'Viščiukų blauzdelės', 'Viščiukų filė', 'Šilauogės', 'Špinatai']
#
# own: ['Bulvės', 'Grietinė', 'Kiaušiniai', 'Kokosų gėrimas', 'Morkos', 'Paprikos', 'Pomidorų pasta', 'Špinatai', 'Burokėliai', 'Druska', 'Imbieras', 'Karis', 'Kefyras', 'Kopūstai', 'Laurų lapai', 'Maltos aitriosios paprikos', 'Pienas UAT', 'Rausvieji svogūnai', 'Sviestinis moliūgas', 'Svogūnai', 'Trumpavaisiai agurkai']
#
# hunt: ['Avietės', 'Aviečių uogienė', 'Džiovinti krapai', 'Svogūnų laiškai', 'Avižų gėrimas', 'Bananai', 'Ridikėliai', 'Skumbrė', 'Sviestas', 'Viščiukų blauzdelės', 'Viščiukų filė', 'Šilauogės', 'Bulvės', 'Grietinė', 'Kiaušiniai', 'Kokosų gėrimas', 'Morkos', 'Paprikos', 'Pomidorų pasta', 'Špinatai']
#
# asap: ['Avietės', 'Aviečių uogienė', 'Džiovinti krapai', 'Svogūnų laiškai']

# %% [markdown]
# ## Check and update your fridge
# Select items that you own in your fridge, want to buy asap or just hunting for a good offer. Your choice will be instantly recorded in a file `fridge\fridge.csv`

# %%
import dash
from dash import dcc, html, Input, Output, State

# Initialize the Dash app
app = dash.Dash(__name__)

items = df['items']
columns = ['own', 'hunt', 'asap']

def mapper_th(name):
    return html.Th(name)

def mapper_td(name, i):
    return html.Td(dcc.Checklist(
                id={'type': f'check_{name}', 'index': i},
                options=[{'label': '', 'value': 'checked'}],
                value=['checked'] if df[name][i] else [],
                inline=True))

# Layout of the app
app.layout = html.Div([
    html.Table([html.Tr([html.Th("item"), *map(mapper_th, columns)]),
               *[html.Tr([html.Td(item), *map(lambda c: mapper_td(c, i), columns)]) 
                 for i, item in enumerate(items)]]),
    html.Div(id='output')
])

# Callback to handle checkbox updates
@app.callback(
    Output('output', 'children'),
    [Input({'type': 'check_own', 'index': dash.dependencies.ALL}, 'value'),
     Input({'type': 'check_hunt', 'index': dash.dependencies.ALL}, 'value'),
     Input({'type': 'check_asap', 'index': dash.dependencies.ALL}, 'value')]
)
def update_checks(own_values, hunt_values, asap_values):
    updated_own = [1 if v else 0 for v in own_values]
    updated_hunt = [1 if v else 0 for v in hunt_values]
    updated_asap = [1 if v else 0 for v in asap_values]
    
    #if item is needed asap that means it's also needed for hunt
    #but too stupid to update checkmark, sorry...
    #updated_hunt = [v1 if v2==0 else 1 for v1, v2 in zip(updated_hunt, updated_asap)]
    
    df['own'], df['hunt'], df['asap'] = updated_own, updated_hunt, updated_asap
    df.to_csv(fridge_file_path, index=False)
    

# Run the app
if __name__ == '__main__':
    app.run(debug=True, jupyter_mode="external")
# Out:
# Dash app running on http://127.0.0.1:8050/

# %% [markdown]
# ## Run scan of every item on watch
# You rn it at the start of a week, takes ~20min

# %%
collect_catalogue(items=items_onwatch, offline=False)
# Out:
# Tracking urls of item = AVIETĖS ... RIMI warning: (no price) https://www.rimi.lt/e-parduotuve/lt/produktai/vaisiai-darzoves-ir-geles/vaisiai-ir-uogos/uogos/lietuviskos-avietes-1-kl-125g/p/903227
# Could not parse url: https://www.rimi.lt/e-parduotuve/lt/produktai/vaisiai-darzoves-ir-geles/vaisiai-ir-uogos/uogos/lietuviskos-avietes-1-kl-125g/p/903227
# Done
# Doneking urls of item = AVIEČIŲ UOGIENĖ ...
# Doneking urls of item = AVIŽŲ GĖRIMAS ...
# Doneking urls of item = BANANAI ...
# RIMI warning: (no price) https://www.rimi.lt/e-parduotuve/lt/produktai/vaisiai-darzoves-ir-geles/darzoves-ir-grybai/bulves/sviezios-lietuviskos-fasuotos-bulves-45-1kg/p/244697
# Could not parse url: https://www.rimi.lt/e-parduotuve/lt/produktai/vaisiai-darzoves-ir-geles/darzoves-ir-grybai/bulves/sviezios-lietuviskos-fasuotos-bulves-45-1kg/p/244697
# Done
# Doneking urls of item = BUROKĖLIAI ...
# Doneking urls of item = DRUSKA ...
# Doneking urls of item = DŽIOVINTI KRAPAI ...
# Doneking urls of item = GRIETINĖ ...
# Doneking urls of item = IMBIERAS ...
# Doneking urls of item = KARIS ...
# Doneking urls of item = KEFYRAS ...
# Doneking urls of item = KIAUŠINIAI ...
# Doneking urls of item = KOKOSŲ GĖRIMAS ...
# Doneking urls of item = KOPŪSTAI ...
# Doneking urls of item = LAURŲ LAPAI ...
# IKI warning: (failed to fetch) https://www.lastmile.lt/chain/IKI/product/Maltos-aitriosios-paprikos-IKI-40-g-259571
# Could not parse url: https://www.lastmile.lt/chain/IKI/product/Maltos-aitriosios-paprikos-IKI-40-g-259571
# Done
# Doneking urls of item = MORKOS ...
# Doneking urls of item = PAPRIKOS ...
# Doneking urls of item = PIENAS UAT ...
# Doneking urls of item = POMIDORŲ PASTA ...
# Doneking urls of item = RAUSVIEJI SVOGŪNAI ...
# Doneking urls of item = RIDIKĖLIAI ...
# Doneking urls of item = SKUMBRĖ ...
# Doneking urls of item = SVIESTAS ...
# RIMI warning: (no price) https://www.rimi.lt/e-parduotuve/lt/produktai/vaisiai-darzoves-ir-geles/darzoves-ir-grybai/svogunai-porai-ir-cesnakai/svogunai-d-40-60mm-kg/p/937069
# Could not parse url: https://www.rimi.lt/e-parduotuve/lt/produktai/vaisiai-darzoves-ir-geles/darzoves-ir-grybai/svogunai-porai-ir-cesnakai/svogunai-d-40-60mm-kg/p/937069
# Done
# Doneking urls of item = SVOGŪNŲ LAIŠKAI ...
# Doneking urls of item = TRUMPAVAISIAI AGURKAI ...
# Doneking urls of item = VIŠČIUKŲ BLAUZDELĖS ...
# IKI warning: (failed to fetch) https://www.lastmile.lt/chain/IKI/product/Sviezia-visciuku-broileriu-file-IKI-MESA-500-g-253573
# Could not parse url: https://www.lastmile.lt/chain/IKI/product/Sviezia-visciuku-broileriu-file-IKI-MESA-500-g-253573
# Done
# MAXIMA parsing error (failed to fetch) https://barbora.lt/produktai/silauoges-500-g
# Could not parse url: https://barbora.lt/produktai/silauoges-500-g
# Done
# IKI warning: (failed to fetch) https://www.lastmile.lt/chain/IKI/product/Mazieji-spinatai-200-g-253970
# Could not parse url: https://www.lastmile.lt/chain/IKI/product/Mazieji-spinatai-200-g-253970
# Done
# {'Avietės':                                                  url  \
#  2  https://barbora.lt/produktai/sald-avietes-well...
#  7  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  3  https://www.lastmile.lt/chain/IKI/product/Avie...
#  4  https://www.lastmile.lt/chain/IKI/product/Avie...
#  0   https://barbora.lt/produktai/avietes-250-g-13955
#  5  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  1  https://barbora.lt/produktai/avietes-well-done...
#  6  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#
#                                                 image  \
#  2  https://cdn.barbora.lt/products/248e6af1-850b-...
#  7  https://rimibaltic-res.cloudinary.com/image/up...
#  3  https://storage.googleapis.com/download/storag...
#  4  https://storage.googleapis.com/download/storag...
#  0  https://cdn.barbora.lt/products/80e91609-f148-...
#  5  https://rimibaltic-res.cloudinary.com/image/up...
#  1  https://cdn.barbora.lt/products/217e0050-d566-...
#  6  https://rimibaltic-res.cloudinary.com/image/up...
#
#                                 title        date    shop  price  \
#  2  Šaldytos avietės WELL DONE, 400 g  2025-09-02  MAXIMA   3.59
#  7       Šaldytos avietės RIMI, 400 g  2025-09-02    RIMI   3.99
#  3                     Avietės, 125 g  2025-09-02     IKI   2.49
#  4                     Avietės, 250 g  2025-09-02     IKI   4.79
#  0                     Avietės, 250 g  2025-09-02  MAXIMA   4.19
#  5                 Avietės RIMI, 225g  2025-09-02    RIMI   4.79
#  1           Avietės WELL DONE, 125 g  2025-09-02  MAXIMA   2.99
#  6                Avietės RIMI, 125 g  2025-09-02    RIMI   2.99
#
#    comparative_unit  comparative_unit_price  discount  discount_price  \
#  2               kg                    8.98     False            3.59
#  7               kg                    9.97     False            3.99
#  3               kg                   19.92      True            1.99
#  4               kg                   19.16      True            3.99
#  0               kg                   16.76     False            4.19
#  5               kg                   21.29     False            4.79
#  1               kg                   23.92     False            2.99
#  6               kg                   23.92     False            2.99
#
#     comparative_unit_discount_price  weight valid_until
#  2                             8.98   0.400
#  7                             9.97   0.400
#  3                            15.92   0.130  2025-09-07
#  4                            15.96   0.270  2025-09-02
#  0                            16.76   0.250
#  5                            21.29   0.225
#  1                            23.92   0.125
#  6                            23.92   0.125              ,
#  'Aviečių uogienė':                                                   url  \
#  0   https://barbora.lt/produktai/avieciu-uogiene-s...
#  8   https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  9   https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  1   https://barbora.lt/produktai/avieciu-uogiene-w...
#  2   https://www.lastmile.lt/chain/PROMO-CashandCar...
#  6   https://www.lastmile.lt/chain/IKI/product/Keda...
#  3   https://www.lastmile.lt/chain/PROMO-CashandCar...
#  7   https://www.lastmile.lt/chain/GERU-MINCIU-uKIS...
#  10  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  4   https://www.lastmile.lt/chain/PROMO-CashandCar...
#  5   https://www.lastmile.lt/chain/PROMO-CashandCar...
#
#                                                  image  \
#  0   https://cdn.barbora.lt/products/a1dda9b4-1afd-...
#  8   https://rimibaltic-res.cloudinary.com/image/up...
#  9   https://rimibaltic-res.cloudinary.com/image/up...
#  1   https://cdn.barbora.lt/products/e42cf8fe-b249-...
#  2   https://firebasestorage.googleapis.com/v0/b/la...
#  6   https://storage.googleapis.com/download/storag...
#  3   https://firebasestorage.googleapis.com/v0/b/la...
#  7   https://storage.googleapis.com/download/storag...
#  10  https://rimibaltic-res.cloudinary.com/image/up...
#  4   https://firebasestorage.googleapis.com/v0/b/la...
#  5   https://firebasestorage.googleapis.com/v0/b/la...
#
#                                          title        date    shop  price  \
#  0              Aviečių uogienė SKANOVĖ, 900 g  2025-09-02  MAXIMA   5.19
#  8   Aviečių uogienė KĖDAINIŲ KONSERVAI, 430 g  2025-09-02    RIMI   3.89
#  9                 Aviečių uogienė PŪRE, 420 g  2025-09-02    RIMI   3.29
#  1            Aviečių uogienė WELL DONE, 350 g  2025-09-02  MAXIMA   2.89
#  2                 Aviečių uogienė PURE, 900 g  2025-09-02     IKI   7.74
#  6             Kėdainių aviečių uogienė, 430 g  2025-09-02     IKI   3.99
#  3             MOČIUTĖS aviečių uogienė, 600 g  2025-09-02     IKI   5.75
#  7            Tradicinė aviečių uogienė, 230 g  2025-09-02     IKI   3.99
#  10              Aviečių uogienė SPILVA, 380 g  2025-09-02    RIMI   3.89
#  4             Aviečių uogienė KĖDAINIŲ, 430 g  2025-09-02     IKI   4.67
#  5             Aviečių uogienė VILROKA, 1,2 kg  2025-09-02     IKI   8.51
#
#     comparative_unit  comparative_unit_price  discount  discount_price  \
#  0                kg                    5.77     False            5.19
#  8                kg                    9.05      True            2.89
#  9                kg                    7.83     False            3.29
#  1                kg                    8.26     False            2.89
#  2                kg                    8.60     False            7.74
#  6                kg                    9.28     False            3.99
#  3                kg                    9.58     False            5.75
#  7                kg                    9.97     False            3.99
#  10               kg                   10.24     False            3.89
#  4                kg                   10.86     False            4.67
#  5                kg                   17.02      True            7.67
#
#      comparative_unit_discount_price  weight valid_until
#  0                              5.77   0.899
#  8                              6.72   0.430  2025-09-08
#  9                              7.83   0.420
#  1                              8.26   0.350
#  2                              8.60   0.900
#  6                              9.28   0.640
#  3                              9.58   0.600
#  7                              9.97   0.400  2024-01-31
#  10                            10.24   0.380
#  4                             10.86   0.430
#  5                             15.34   0.500  2025-09-30  ,
#  'Avižų gėrimas':                                                   url  \
#  3   https://barbora.lt/produktai/avizu-gerimas-far...
#  8   https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  7   https://www.lastmile.lt/chain/IKI/product/Ekol...
#  13  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  1   https://barbora.lt/produktai/avizu-gerimas-nat...
#  4   https://barbora.lt/produktai/ekologiskas-avizu...
#  6   https://www.lastmile.lt/chain/IKI/product/Aviz...
#  10  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  11  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  12  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  5   https://www.lastmile.lt/chain/IKI/product/Aviz...
#  9   https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  0   https://barbora.lt/produktai/avizu-gerimas-alp...
#  2   https://barbora.lt/produktai/avizu-gerimas-alp...
#
#                                                  image  \
#  3   https://cdn.barbora.lt/products/1343ee5f-3173-...
#  8   https://rimibaltic-res.cloudinary.com/image/up...
#  7   https://firebasestorage.googleapis.com/v0/b/la...
#  13  https://rimibaltic-res.cloudinary.com/image/up...
#  1   https://cdn.barbora.lt/products/9569cb96-d508-...
#  4   https://cdn.barbora.lt/products/939fbc21-08ee-...
#  6   https://firebasestorage.googleapis.com/v0/b/la...
#  10  https://rimibaltic-res.cloudinary.com/image/up...
#  11  https://rimibaltic-res.cloudinary.com/image/up...
#  12  https://rimibaltic-res.cloudinary.com/image/up...
#  5   https://firebasestorage.googleapis.com/v0/b/la...
#  9   https://rimibaltic-res.cloudinary.com/image/up...
#  0   https://cdn.barbora.lt/products/d1351cd6-d405-...
#  2   https://cdn.barbora.lt/products/d6ce8ac8-3793-...
#
#                                                  title        date    shop  \
#  3                        Avižų gėrimas FARM MILK, 1 l  2025-09-02  MAXIMA
#  8                               Avižų gėrimas ICA, 1l  2025-09-02    RIMI
#  7                Ekologiškas avižų gėrimas MARGĖ, 1 l  2025-09-02     IKI
#  13      Avižų ir braškių - ban. sulčių gėr. CIDO, 1 l  2025-09-02    RIMI
#  1                         Avižų gėrimas NATURLI', 1 l  2025-09-02  MAXIMA
#  4   Ekologiškas avižų gėrimas be pridėtinio cukrau...  2025-09-02  MAXIMA
#  6                             Avižų gėrimas ALPRO, 1l  2025-09-02     IKI
#  10                   Avižų gėrimas YOOK  BARISTA, 1 l  2025-09-02    RIMI
#  11               Augalinis avižų gėrimas VALSOIA, 1 l  2025-09-02    RIMI
#  12              Avižų gėrimas TERE DEARY Barista, 1 l  2025-09-02    RIMI
#  5   Avižų augalinis gėrimas su kalciu ir vitaminai...  2025-09-02     IKI
#  9                Ekologiškas avižų gėrimas OATLY, 1 l  2025-09-02    RIMI
#  0                            Avižų gėrimas ALPRO, 1 l  2025-09-02  MAXIMA
#  2                    Avižų gėrimas ALPRO BARISTA, 1 l  2025-09-02  MAXIMA
#
#      price comparative_unit  comparative_unit_price  discount  discount_price  \
#  3    1.59                l                    1.59     False            1.59
#  8    1.69                l                    1.69     False            1.69
#  7    2.29                l                    2.29     False            2.29
#  13   2.29                l                    2.29     False            2.29
#  1    2.99                l                    2.99      True            2.49
#  4    2.49                l                    2.49     False            2.49
#  6    3.29                l                    3.29      True            2.63
#  10   2.89                l                    2.89     False            2.89
#  11   2.89                l                    2.89     False            2.89
#  12   2.89                l                    2.89     False            2.89
#  5    2.99                l                    2.99     False            2.99
#  9    2.99                l                    2.99     False            2.99
#  0    3.19                l                    3.19     False            3.19
#  2    3.69                l                    3.69     False            3.69
#
#      comparative_unit_discount_price  weight valid_until
#  3                              1.59    1.00
#  8                              1.69    1.00
#  7                              2.29    1.04
#  13                             2.29    1.00
#  1                              2.49    1.00  2025-09-08
#  4                              2.49    1.00
#  6                              2.63    1.06  2025-09-07
#  10                             2.89    1.00
#  11                             2.89    1.00
#  12                             2.89    1.00
#  5                              2.99    1.04
#  9                              2.99    1.00
#  0                              3.19    1.00
#  2                              3.69    1.00              ,
#  'Bananai':                                                  url  \
#  1  https://www.lastmile.lt/chain/IKI/product/Bana...
#  0          https://barbora.lt/produktai/bananai-1-kg
#  2  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#
#                                                 image  \
#  1  https://firebasestorage.googleapis.com/v0/b/la...
#  0  https://cdn.barbora.lt/products/1d747537-6760-...
#  2  https://rimibaltic-res.cloudinary.com/image/up...
#
#                              title        date    shop  price comparative_unit  \
#  1                 Bananai BON VIA  2025-09-02     IKI   1.39               kg
#  0        Bananai, nuo 20 cm, 1 kg  2025-09-02  MAXIMA   1.39               kg
#  2  Bananai Cavendish, 20+cm , 1kg  2025-09-02    RIMI   1.39               kg
#
#     comparative_unit_price  discount  discount_price  \
#  1                    1.39      True            0.99
#  0                    1.39     False            1.39
#  2                    1.39     False            1.39
#
#     comparative_unit_discount_price  weight valid_until
#  1                             0.99     1.0  2025-09-07
#  0                             1.39     1.0
#  2                             1.39     1.0              ,
#  'Bulvės':                                                  url  \
#  2  https://www.lastmile.lt/chain/PROMO-CashandCar...
#  1  https://www.lastmile.lt/chain/IKI/product/Sver...
#  0  https://barbora.lt/produktai/lietuviskos-sviez...
#
#                                                 image  \
#  2  https://storage.googleapis.com/download/storag...
#  1  https://storage.googleapis.com/download/storag...
#  0  https://cdn.barbora.lt/products/1f910506-fa6a-...
#
#                                           title        date    shop  price  \
#  2      Sveriamos bulvės, 50-70 mm, I klasė, kg  2025-09-02     IKI   0.79
#  1                     Sveriamos bulvės CLEVER   2025-09-02     IKI   0.69
#  0  Lietuviškos šviežios bulvės, 40-60 mm, 1 kg  2025-09-02  MAXIMA   0.75
#
#    comparative_unit  comparative_unit_price  discount  discount_price  \
#  2               kg                    0.79      True            0.57
#  1               kg                    0.69     False            0.69
#  0               kg                    0.75     False            0.75
#
#     comparative_unit_discount_price  weight valid_until
#  2                             0.57     1.0  2025-09-03
#  1                             0.69     1.0
#  0                             0.75     1.0              ,
#  'Burokėliai':                                                  url  \
#  2  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  0  https://barbora.lt/produktai/lietuviski-buroke...
#  1  https://www.lastmile.lt/chain/IKI/product/Buro...
#
#                                                 image  \
#  2  https://rimibaltic-res.cloudinary.com/image/up...
#  0  https://cdn.barbora.lt/products/911300d5-03a6-...
#  1  https://storage.googleapis.com/download/storag...
#
#                           title        date    shop  price comparative_unit  \
#  2  Lietuviški burokėliai, 1 kg  2025-09-02    RIMI   0.65               kg
#  0  Lietuviški burokėliai, 1 kg  2025-09-02  MAXIMA   0.79               kg
#  1           Burokėliai CLEVER   2025-09-02     IKI   0.99               kg
#
#     comparative_unit_price  discount  discount_price  \
#  2                    0.65     False            0.65
#  0                    0.79     False            0.79
#  1                    0.99     False            0.99
#
#     comparative_unit_discount_price  weight valid_until
#  2                             0.65     1.0
#  0                             0.79     1.0
#  1                             0.99     1.0              ,
#  'Druska':                                                  url  \
#  2  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  0  https://barbora.lt/produktai/joduotoji-druska-...
#  1  https://www.lastmile.lt/chain/IKI/product/Valg...
#
#                                                 image  \
#  2  https://rimibaltic-res.cloudinary.com/image/up...
#  0  https://cdn.barbora.lt/products/a26d81d0-3afb-...
#  1  https://storage.googleapis.com/download/storag...
#
#                                       title        date    shop  price  \
#  2        Valgomoji druska RIMI SMART, 1 kg  2025-09-02    RIMI   0.39
#  0   Joduotoji druska EXTRA LINE, 1kg, 1 kg  2025-09-02  MAXIMA   0.45
#  1  Valgomoji akmens druska SALT HILL, 1 kg  2025-09-02     IKI   0.65
#
#    comparative_unit  comparative_unit_price  discount  discount_price  \
#  2               kg                    0.39     False            0.39
#  0               kg                    0.45     False            0.45
#  1               kg                    0.65     False            0.65
#
#     comparative_unit_discount_price  weight valid_until
#  2                             0.39    1.00
#  0                             0.45    1.00
#  1                             0.65    1.01              ,
#  'Džiovinti krapai':                                                  url  \
#  2  https://www.lastmile.lt/chain/PROMO-CashandCar...
#  3  https://www.lastmile.lt/chain/PROMO-CashandCar...
#  1  https://barbora.lt/produktai/krapai-well-done-...
#  0  https://barbora.lt/produktai/dziovinti-krapai-...
#  4  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#
#                                                 image  \
#  2  https://firebasestorage.googleapis.com/v0/b/la...
#  3  https://firebasestorage.googleapis.com/v0/b/la...
#  1  https://cdn.barbora.lt/products/970d068f-9e89-...
#  0  https://cdn.barbora.lt/products/c8397efc-807a-...
#  4  https://rimibaltic-res.cloudinary.com/image/up...
#
#                                        title        date    shop  price  \
#  2                   Džiovinti krapai, 100 g  2025-09-02     IKI   0.86
#  3                   Džiovinti krapai, 500 g  2025-09-02     IKI   3.44
#  1                    Krapai WELL DONE, 30 g  2025-09-02  MAXIMA   0.99
#  0              Džiovinti krapai SAUDA, 15 g  2025-09-02  MAXIMA   0.55
#  4  Krapų viršūnėlės TASTE FROM GARDEN, 30 g  2025-09-02    RIMI   1.25
#
#    comparative_unit  comparative_unit_price  discount  discount_price  \
#  2               kg                    1.72      True            0.72
#  3               kg                    6.88     False            3.44
#  1               kg                   33.00     False            0.99
#  0               kg                   36.67     False            0.55
#  4               kg                   41.67     False            1.25
#
#     comparative_unit_discount_price  weight valid_until
#  2                             1.44   0.500  2025-09-02
#  3                             6.88   0.500
#  1                            33.00   0.030
#  0                            36.67   0.015
#  4                            41.67   0.030              ,
#  'Grietinė':                                                   url  \
#  10  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  4   https://www.lastmile.lt/chain/IKI/product/Grie...
#  0   https://barbora.lt/produktai/grietine-farm-mil...
#  13  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  6   https://www.lastmile.lt/chain/IKI/product/Grie...
#  3   https://barbora.lt/produktai/naturali-rokiskio...
#  8   https://www.lastmile.lt/chain/IKI/product/Grie...
#  9   https://www.lastmile.lt/chain/IKI/product/ROKI...
#  2   https://barbora.lt/produktai/rokiskio-namine-g...
#  11  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  5   https://www.lastmile.lt/chain/IKI/product/Grie...
#  7   https://www.lastmile.lt/chain/IKI/product/Grie...
#  1   https://barbora.lt/produktai/grietine-well-don...
#  12  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#
#                                                  image  \
#  10  https://rimibaltic-res.cloudinary.com/image/up...
#  4   https://storage.googleapis.com/download/storag...
#  0   https://cdn.barbora.lt/products/f97b5c02-61b7-...
#  13  https://rimibaltic-res.cloudinary.com/image/up...
#  6   https://firebasestorage.googleapis.com/v0/b/la...
#  3   https://cdn.barbora.lt/products/7f80c48f-7e7a-...
#  8   https://storage.googleapis.com/download/storag...
#  9   https://firebasestorage.googleapis.com/v0/b/la...
#  2   https://cdn.barbora.lt/products/0f3c6ed0-a49f-...
#  11  https://rimibaltic-res.cloudinary.com/image/up...
#  5   https://storage.googleapis.com/download/storag...
#  7   https://storage.googleapis.com/download/storag...
#  1   https://cdn.barbora.lt/products/06fa9761-7c49-...
#  12  https://rimibaltic-res.cloudinary.com/image/up...
#
#                                                  title        date    shop  \
#  10             Grietinė RIMI SMART, 30 % rieb., 400 g  2025-09-02    RIMI
#  4                    Grietinė 30% rieb. CLEVER, 400 g  2025-09-02     IKI
#  0               Grietinė FARM MILK, 30 % rieb., 400 g  2025-09-02  MAXIMA
#  13              ROKIŠKIO NAMINĖ grietinė, 30 %, 500 g  2025-09-02    RIMI
#  6          Grietinė 30% riebumo ŽALOJI KARVUTĖ, 400 g  2025-09-02     IKI
#  3   Natūrali ROKIŠKIO grietinė ŽALOJI KARVUTĖ, 30 ...  2025-09-02  MAXIMA
#  8                    Grietinė DVARO, 30% rieb., 500 g  2025-09-02     IKI
#  9          ROKIŠKIO NAMINĖ GRIETINĖ 30 % RIEB.,/500 G  2025-09-02     IKI
#  2         ROKIŠKIO NAMINĖ grietinė, 30 % rieb., 500 g  2025-09-02  MAXIMA
#  11                  DVARO grietinė, 30 % rieb., 500 g  2025-09-02    RIMI
#  5                       Grietinė 30% rieb. IKI, 400 g  2025-09-02     IKI
#  7                      Grietinė ŽALOJI KARVUTĖ, 400 g  2025-09-02     IKI
#  1               Grietinė WELL DONE, 30 % rieb., 400 g  2025-09-02  MAXIMA
#  12                   Grietinė RIMI, 30 % rieb., 200 g  2025-09-02    RIMI
#
#      price comparative_unit  comparative_unit_price  discount  discount_price  \
#  10   1.59               kg                    3.97     False            1.59
#  4    1.59               kg                    3.98     False            1.59
#  0    1.59               kg                    3.98     False            1.59
#  13   3.19               kg                    6.38      True            2.69
#  6    2.39               kg                    5.97     False            2.39
#  3    2.39               kg                    5.98     False            2.39
#  8    3.19               kg                    6.38     False            3.19
#  9    3.19               kg                    6.38     False            3.19
#  2    3.19               kg                    6.38     False            3.19
#  11   3.19               kg                    6.38     False            3.19
#  5    2.69               kg                    6.72     False            2.69
#  7    2.69               kg                    6.72     False            2.69
#  1    2.69               kg                    6.73     False            2.69
#  12   1.59               kg                    7.95     False            1.59
#
#      comparative_unit_discount_price  weight valid_until
#  10                             3.97   0.401
#  4                              3.98   0.530
#  0                              3.98   0.399
#  13                             5.38   0.500  2025-09-08
#  6                              5.97   0.410
#  3                              5.98   0.400
#  8                              6.38   0.500
#  9                              6.38   0.570
#  2                              6.38   0.500
#  11                             6.38   0.500
#  5                              6.72   0.420
#  7                              6.72   0.410
#  1                              6.73   0.400
#  12                             7.95   0.200              ,
#  'Imbieras':                                                  url  \
#  0   https://barbora.lt/produktai/imbieru-saknys-1-kg
#  2  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  1  https://www.lastmile.lt/chain/IKI/product/Imbi...
#
#                                                 image                 title  \
#  0  https://cdn.barbora.lt/products/7b13c6d7-627b-...  Imbierų šaknys, 1 kg
#  2  https://rimibaltic-res.cloudinary.com/image/up...   Imbierų šaknys, 1kg
#  1  https://storage.googleapis.com/download/storag...             Imbierai
#
#           date    shop  price comparative_unit  comparative_unit_price  \
#  0  2025-09-02  MAXIMA   5.49               kg                    5.49
#  2  2025-09-02    RIMI   5.49               kg                    5.49
#  1  2025-09-02     IKI   5.99               kg                    5.99
#
#     discount  discount_price  comparative_unit_discount_price  weight  \
#  0     False            5.49                             5.49     1.0
#  2     False            5.49                             5.49     1.0
#  1     False            5.99                             5.99     1.0
#
#    valid_until
#  0
#  2
#  1              ,
#  'Karis':                                                  url  \
#  1  https://barbora.lt/produktai/karis-well-done-40-g
#  5  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  3  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  4  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  2  https://www.lastmile.lt/chain/IKI/product/Kari...
#  0  https://barbora.lt/produktai/karis-santa-maria...
#
#                                                 image  \
#  1  https://cdn.barbora.lt/products/594bc7c6-6b6c-...
#  5  https://rimibaltic-res.cloudinary.com/image/up...
#  3  https://rimibaltic-res.cloudinary.com/image/up...
#  4  https://rimibaltic-res.cloudinary.com/image/up...
#  2  https://storage.googleapis.com/download/storag...
#  0  https://cdn.barbora.lt/products/d57573ed-24fa-...
#
#                                    title        date    shop  price  \
#  1                 Karis WELL DONE, 40 g  2025-09-02  MAXIMA   0.89
#  5           Kario prieskoniai RIMI, 25g  2025-09-02    RIMI   0.59
#  3                Karis SANTA MARIA, 25g  2025-09-02    RIMI   1.05
#  4  Prieskonių mišinys karis SALDVA, 25g  2025-09-02    RIMI   0.79
#  2               Karis SANTA MARIA, 25 g  2025-09-02     IKI   0.99
#  0               Karis SANTA MARIA, 25 g  2025-09-02  MAXIMA   0.99
#
#    comparative_unit  comparative_unit_price  discount  discount_price  \
#  1               kg                   22.25     False            0.89
#  5               kg                   23.60     False            0.59
#  3               kg                   42.00      True            0.68
#  4               kg                   31.60     False            0.79
#  2               kg                   39.60     False            0.99
#  0               kg                   39.60     False            0.99
#
#     comparative_unit_discount_price  weight valid_until
#  1                            22.25   0.040
#  5                            23.60   0.025
#  3                            27.20   0.025  2025-09-08
#  4                            31.60   0.025
#  2                            39.60   0.040
#  0                            39.60   0.025              ,
#  'Kefyras':                                                  url  \
#  5  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  3  https://www.lastmile.lt/chain/IKI/product/Kefy...
#  1  https://barbora.lt/produktai/kefyras-farm-milk...
#  0  https://barbora.lt/produktai/kefyras-farm-milk...
#  2  https://barbora.lt/produktai/saltibarsciu-kefy...
#  4  https://www.lastmile.lt/chain/IKI/product/Salt...
#
#                                                 image  \
#  5  https://rimibaltic-res.cloudinary.com/image/up...
#  3  https://storage.googleapis.com/download/storag...
#  1  https://cdn.barbora.lt/products/010d0148-5e95-...
#  0  https://cdn.barbora.lt/products/4872af65-b738-...
#  2  https://cdn.barbora.lt/products/22224f96-7105-...
#  4  https://firebasestorage.googleapis.com/v0/b/la...
#
#                                                 title        date    shop  \
#  5            Kefyras RIMI SMART, 2,5 % rieb., 0,9 kg  2025-09-02    RIMI
#  3                   Kefyras 2,5% rieb. CLEVER, 900 g  2025-09-02     IKI
#  1               Kefyras FARM MILK, 2,5 % rieb., 1 kg  2025-09-02  MAXIMA
#  0                 Kefyras FARM MILK, 2 % rieb., 1 kg  2025-09-02  MAXIMA
#  2    Šaltibarščių kefyras WELL DONE, 5 % rieb., 1 kg  2025-09-02  MAXIMA
#  4  Šaltibarščių kefyras ŽALOJI KARVUTĖ, 5% rieb.,...  2025-09-02     IKI
#
#     price comparative_unit  comparative_unit_price  discount  discount_price  \
#  5   0.74               kg                    0.82     False            0.74
#  3   0.76               kg                    0.84     False            0.76
#  1   0.85               kg                    0.85     False            0.85
#  0   0.95               kg                    0.95     False            0.95
#  2   1.49               kg                    1.49     False            1.49
#  4   1.59               kg                    1.59     False            1.59
#
#     comparative_unit_discount_price  weight valid_until
#  5                             0.82   0.902
#  3                             0.84   0.910
#  1                             0.85   1.000
#  0                             0.95   1.000
#  2                             1.49   1.000
#  4                             1.59   1.000              ,
#  'Kiaušiniai':                                                  url  \
#  0  https://barbora.lt/produktai/ant-kraiko-laikom...
#  2  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  1  https://www.lastmile.lt/chain/IKI/product/Kiau...
#
#                                                 image  \
#  0  https://cdn.barbora.lt/products/7a442559-0a9a-...
#  2  https://rimibaltic-res.cloudinary.com/image/up...
#  1  https://firebasestorage.googleapis.com/v0/b/la...
#
#                                                 title        date    shop  \
#  0       Ant kraiko laikomų vištų kiaušiniai, 10 vnt.  2025-09-02  MAXIMA
#  2            Vištų kiaušiniai RIMI, A/LM Nr.2, 10vnt  2025-09-02    RIMI
#  1  Kiaušiniai IKI ant kraiko laikomų vištų M dydž...  2025-09-02     IKI
#
#     price comparative_unit  comparative_unit_price  discount  discount_price  \
#  0   2.15              vnt                    0.22     False            2.15
#  2   2.15              vnt                    0.22     False            2.15
#  1   2.49              vnt                    0.25     False            2.49
#
#     comparative_unit_discount_price valid_until  weight
#  0                             0.22                 NaN
#  2                             0.22                 NaN
#  1                             0.25                 0.6  ,
#  'Kokosų gėrimas':                                                  url  \
#  5  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  7  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  8  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  1  https://barbora.lt/produktai/kokosu-gerimas-ex...
#  0  https://barbora.lt/produktai/kokosu-gerimas-aj...
#  2  https://barbora.lt/produktai/ekologiskas-kokos...
#  3  https://www.lastmile.lt/chain/IKI/product/Koko...
#  4  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  6  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#
#                                                 image  \
#  5  https://rimibaltic-res.cloudinary.com/image/up...
#  7  https://rimibaltic-res.cloudinary.com/image/up...
#  8  https://rimibaltic-res.cloudinary.com/image/up...
#  1  https://cdn.barbora.lt/products/b35b21e5-4749-...
#  0  https://cdn.barbora.lt/products/de61ce76-a99a-...
#  2  https://cdn.barbora.lt/products/bdb47979-b656-...
#  3  https://firebasestorage.googleapis.com/v0/b/la...
#  4  https://rimibaltic-res.cloudinary.com/image/up...
#  6  https://rimibaltic-res.cloudinary.com/image/up...
#
#                                               title        date    shop  price  \
#  5                        Kokosų gėrimas AJI, 400ml  2025-09-02    RIMI   2.09
#  7                  Kokosų gėrimas ICA ASIA, 200 ml  2025-09-02    RIMI   1.45
#  8            Kokosų gėrimas ICA ASIA LIGHT, 400 ml  2025-09-02    RIMI   3.19
#  1       Kokosų gėrimas EXTRA LINE, 17-19 %, 400 ml  2025-09-02  MAXIMA   1.89
#  0                       Kokosų gėrimas AJI, 400 ml  2025-09-02  MAXIMA   1.99
#  2  Ekologiškas kokosų gėrimas BIONATURALIS, 400 ml  2025-09-02  MAXIMA   2.89
#  3                     Kokosų gėrimas BILLA, 400 ml  2025-09-02     IKI   2.29
#  4                Kokosų gėrimas I LOVE ECO, 400 ml  2025-09-02    RIMI   2.29
#  6                Kokosų gėrimas THAI CHOICE, 400ml  2025-09-02    RIMI   3.99
#
#    comparative_unit  comparative_unit_price  discount  discount_price  \
#  5                l                    5.22      True            1.45
#  7                l                    7.25      True            0.87
#  8                l                    7.97      True            1.89
#  1                l                    4.73     False            1.89
#  0                l                    4.98     False            1.99
#  2                l                    7.23      True            2.16
#  3                l                    5.72     False            2.29
#  4                l                    5.72     False            2.29
#  6                l                    9.97     False            3.99
#
#     comparative_unit_discount_price  weight valid_until
#  5                             3.62    0.40  2025-09-08
#  7                             4.35    0.20  2025-09-08
#  8                             4.72    0.40  2025-09-08
#  1                             4.73    0.40
#  0                             4.98    0.40
#  2                             5.40    0.40  2025-09-08
#  3                             5.72    0.46
#  4                             5.72    0.40
#  6                             9.97    0.40              ,
#  'Kopūstai':                                                  url  \
#  1  https://www.lastmile.lt/chain/IKI/product/Kopu...
#  0  https://barbora.lt/produktai/lietuviski-sviezi...
#  2  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#
#                                                 image  \
#  1  https://storage.googleapis.com/download/storag...
#  0  https://cdn.barbora.lt/products/bc6b0e73-b088-...
#  2  https://rimibaltic-res.cloudinary.com/image/up...
#
#                                          title        date    shop  price  \
#  1                            Kopūstai CLEVER   2025-09-02     IKI   0.99
#  0           Švieži baltagūžiai kopūstai, 1 kg  2025-09-02  MAXIMA   1.19
#  2  Lietuviški švieži baltagūžiai kopūstai, kg  2025-09-02    RIMI   1.19
#
#    comparative_unit  comparative_unit_price  discount  discount_price  \
#  1               kg                    0.99      True            0.47
#  0               kg                    1.19      True            0.59
#  2               kg                    1.19     False            1.19
#
#     comparative_unit_discount_price  weight valid_until
#  1                             0.47     1.0  2025-09-07
#  0                             0.59     1.0  2025-09-08
#  2                             1.19     1.0              ,
#  'Laurų lapai':                                                  url  \
#  5  https://www.lastmile.lt/chain/IKI/product/Laur...
#  4  https://www.lastmile.lt/chain/PROMO-CashandCar...
#  3  https://www.lastmile.lt/chain/PROMO-CashandCar...
#  0  https://barbora.lt/produktai/lauru-lapai-sauda...
#  6  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  1  https://barbora.lt/produktai/lauru-lapai-well-...
#  2  https://barbora.lt/produktai/malti-lauru-lapel...
#
#                                                 image  \
#  5  https://storage.googleapis.com/download/storag...
#  4  https://storage.googleapis.com/download/storag...
#  3  https://storage.googleapis.com/download/storag...
#  0  https://cdn.barbora.lt/products/4a539fcc-d8c9-...
#  6  https://rimibaltic-res.cloudinary.com/image/up...
#  1  https://cdn.barbora.lt/products/280f3944-e550-...
#  2  https://cdn.barbora.lt/products/8536fd72-5920-...
#
#                                 title        date    shop  price  \
#  5            Laurų lapai SAUDA, 40 g  2025-09-02     IKI   0.79
#  4            Laurų lapai SAUDA, 40 g  2025-09-02     IKI   0.60
#  3                 Laurų lapai, 100 g  2025-09-02     IKI   1.83
#  0            Laurų lapai SAUDA, 40 g  2025-09-02  MAXIMA   0.79
#  6             Laurų lapai SAUDA, 40g  2025-09-02    RIMI   0.79
#  1        Laurų lapai WELL DONE, 40 g  2025-09-02  MAXIMA   0.99
#  2  Malti laurų lapeliai SALDVA, 20 g  2025-09-02  MAXIMA   0.65
#
#    comparative_unit  comparative_unit_price  discount  discount_price  \
#  5               kg                   19.75      True            0.55
#  4               kg                   15.00     False            0.60
#  3               kg                   18.30      True            1.53
#  0               kg                   19.75     False            0.79
#  6               kg                   19.75     False            0.79
#  1               kg                   24.75     False            0.99
#  2               kg                   32.50     False            0.65
#
#     comparative_unit_discount_price  weight valid_until
#  5                            13.75    0.05  2025-09-07
#  4                            15.00    0.04
#  3                            15.30    0.10  2025-09-02
#  0                            19.75    0.04
#  6                            19.75    0.04
#  1                            24.75    0.04
#  2                            32.50    0.02              ,
#  'Maltos aitriosios paprikos':                                                  url  \
#  1  https://barbora.lt/produktai/maltos-aitriosios...
#  0  https://barbora.lt/produktai/maltos-aitriosios...
#  2  https://www.lastmile.lt/chain/IKI/product/Aitr...
#  3  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#
#                                                 image  \
#  1  https://cdn.barbora.lt/products/057a8abe-080d-...
#  0  https://cdn.barbora.lt/products/312488ca-6c82-...
#  2  https://storage.googleapis.com/download/storag...
#  3  https://rimibaltic-res.cloudinary.com/image/up...
#
#                                          title        date    shop  price  \
#  1  Maltos aitriosios paprikos WELL DONE, 40 g  2025-09-02  MAXIMA   0.99
#  0     Maltos aitriosios paprikos SALDVA, 25 g  2025-09-02  MAXIMA   0.69
#  2        Aitrioji raudonoji paprika IKI, 50 g  2025-09-02     IKI   1.49
#  3      Malta aitriosioji paprika SALDVA, 25 g  2025-09-02    RIMI   0.80
#
#    comparative_unit  comparative_unit_price  discount  discount_price  \
#  1               kg                   24.75     False            0.99
#  0               kg                   27.60     False            0.69
#  2               kg                   29.80     False            1.49
#  3               kg                   32.00     False            0.80
#
#     comparative_unit_discount_price  weight valid_until
#  1                            24.75   0.040
#  0                            27.60   0.025
#  2                            29.80   0.060
#  3                            32.00   0.025              ,
#  'Morkos':                                                  url  \
#  2  https://www.lastmile.lt/chain/IKI/product/Plau...
#  4  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  3  https://www.lastmile.lt/chain/PROMO-CashandCar...
#  0   https://barbora.lt/produktai/plautos-morkos-1-kg
#  1  https://www.lastmile.lt/chain/IKI/product/Fasu...
#
#                                                 image  \
#  2  https://storage.googleapis.com/download/storag...
#  4  https://rimibaltic-res.cloudinary.com/image/up...
#  3  https://storage.googleapis.com/download/storag...
#  0  https://cdn.barbora.lt/products/c19c320d-a3d6-...
#  1  https://storage.googleapis.com/download/storag...
#
#                              title        date    shop  price comparative_unit  \
#  2           Plautos morkos CLEVER  2025-09-02     IKI   0.79               kg
#  4  Lietuviškos plautos morkos, kg  2025-09-02    RIMI   0.65               kg
#  3   Sveriamos morkos, I klasė, kg  2025-09-02     IKI   0.66               kg
#  0            Plautos morkos, 1 kg  2025-09-02  MAXIMA   0.89               kg
#  1  Fasuotos morkos IKI ŪKIS, 1 kg  2025-09-02     IKI   1.19               kg
#
#     comparative_unit_price  discount  discount_price  \
#  2                    0.79      True            0.59
#  4                    0.65     False            0.65
#  3                    0.66     False            0.66
#  0                    0.89     False            0.89
#  1                    1.19     False            1.19
#
#     comparative_unit_discount_price  weight valid_until
#  2                             0.59    1.00  2025-09-07
#  4                             0.65    1.00
#  3                             0.66    1.00
#  0                             0.89    1.00
#  1                             1.19    1.05              ,
#  'Paprikos':                                                   url  \
#  8   https://www.lastmile.lt/chain/IKI/product/Balt...
#  6   https://www.lastmile.lt/chain/IKI/product/Raud...
#  5   https://www.lastmile.lt/chain/PROMO-CashandCar...
#  7   https://www.lastmile.lt/chain/IKI/product/Gelt...
#  14  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  0   https://barbora.lt/produktai/raudonos-saldzios...
#  10  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  3   https://www.lastmile.lt/chain/PROMO-CashandCar...
#  11  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  2   https://www.lastmile.lt/chain/PROMO-CashandCar...
#  9   https://www.lastmile.lt/chain/Assorti/product/...
#  1   https://barbora.lt/produktai/geltonos-saldzios...
#  13  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  12  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  4   https://www.lastmile.lt/chain/PROMO-CashandCar...
#
#                                                  image  \
#  8   https://storage.googleapis.com/download/storag...
#  6   https://firebasestorage.googleapis.com/v0/b/la...
#  5   https://firebasestorage.googleapis.com/v0/b/la...
#  7   https://firebasestorage.googleapis.com/v0/b/la...
#  14  https://rimibaltic-res.cloudinary.com/image/up...
#  0   https://cdn.barbora.lt/products/544567df-0d36-...
#  10  https://rimibaltic-res.cloudinary.com/image/up...
#  3   https://firebasestorage.googleapis.com/v0/b/la...
#  11  https://rimibaltic-res.cloudinary.com/image/up...
#  2   https://firebasestorage.googleapis.com/v0/b/la...
#  9   https://firebasestorage.googleapis.com/v0/b/la...
#  1   https://cdn.barbora.lt/products/aec1c953-b49d-...
#  13  https://rimibaltic-res.cloudinary.com/image/up...
#  12  https://rimibaltic-res.cloudinary.com/image/up...
#  4   https://firebasestorage.googleapis.com/v0/b/la...
#
#                                                 title        date    shop  \
#  8                                Baltosios paprikos   2025-09-02     IKI
#  6                       Raudonosios paprikos BON VIA  2025-09-02     IKI
#  5         Paprikos, saldžiosios, žalios, I klasė, kg  2025-09-02     IKI
#  7                       Geltonosios paprikos BON VIA  2025-09-02     IKI
#  14                   Baltosios paprikos, 1 kl., 1 kg  2025-09-02    RIMI
#  0     Raudonos saldžiosios paprikos, 80-100 mm, 1 kg  2025-09-02  MAXIMA
#  10     Raudonos saldžiosios paprikos (70+mm),1kl,1kg  2025-09-02    RIMI
#  3       Paprikos, saldžiosios, raudonos, I klasė, kg  2025-09-02     IKI
#  11     Geltonos saldžiosios paprikos (80+mm),1kl,1kg  2025-09-02    RIMI
#  2       Paprikos, saldžiosios, geltonos, I klasė, kg  2025-09-02     IKI
#  9   Raudonos saldžiosios paprikos (70-90 mm), II kl.  2025-09-02     IKI
#  1     Geltonos saldžiosios paprikos, 80-100 mm, 1 kg  2025-09-02  MAXIMA
#  13          Žaliosios paprikos (75+ mm), 1 kl., 1 kg  2025-09-02    RIMI
#  12     Oranžin. saldžiosios paprikos (80+mm),1kl,1kg  2025-09-02    RIMI
#  4      Paprikos, saldžiosios, oranžinės, I klasė, kg  2025-09-02     IKI
#
#      price comparative_unit  comparative_unit_price  discount  discount_price  \
#  8    2.99               kg                    2.99      True            2.09
#  6    3.49               kg                    3.49      True            2.44
# ...
#  2                                    Svogūnų laiškai  2025-09-02     IKI
#  3                             Svogūnų laiškai, 100 g  2025-09-02     IKI
#  0  Svogūnų laiškai LINKĖJIMAI IŠ KAIMO (fasuoti),...  2025-09-02  MAXIMA
#  5                      Fasuoti svogūnų laiškai, 50 g  2025-09-02    RIMI
#  4                            Žalumynų rinkinys, 70 g  2025-09-02     IKI
#  1  Žalumynų rinkinys: svogūnų laiškai ir krapai, ...  2025-09-02  MAXIMA
#
#     price comparative_unit  comparative_unit_price  discount  discount_price  \
#  2   8.99               kg                    8.99     False            8.99
#  3   1.59               kg                   15.90     False            1.59
#  0   1.59               kg                   15.90     False            1.59
#  5   0.99               kg                   19.80     False            0.99
#  4   1.59               kg                   22.71     False            1.59
#  1   1.59               kg                   22.71     False            1.59
#
#     comparative_unit_discount_price  weight valid_until
#  2                             8.99    1.00
#  3                            15.90    0.10
#  0                            15.90    0.10
#  5                            19.80    0.05
#  4                            22.71    0.07
#  1                            22.71    0.07              ,
#  'Trumpavaisiai agurkai':                                                  url  \
#  0  https://barbora.lt/produktai/lietuviski-trumpa...
#  2  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  1  https://www.lastmile.lt/chain/IKI/product/Liet...
#  3  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#
#                                                 image  \
#  0  https://cdn.barbora.lt/products/1fb22e11-6d00-...
#  2  https://rimibaltic-res.cloudinary.com/image/up...
#  1  https://storage.googleapis.com/download/storag...
#  3  https://rimibaltic-res.cloudinary.com/image/up...
#
#                                             title        date    shop  price  \
#  0         Lietuviški trumpavaisiai agurkai, 1 kg  2025-09-02  MAXIMA   2.99
#  2           Lietuviški trumpavaisiai agurkai, kg  2025-09-02    RIMI   2.99
#  1              Lietuviški trumpavaisiai agurkai   2025-09-02     IKI   2.99
#  3  Lietuviški fasuoti trumpavaisiai agurkai,500g  2025-09-02    RIMI   1.89
#
#    comparative_unit  comparative_unit_price  discount  discount_price  \
#  0               kg                    2.99      True            1.89
#  2               kg                    2.99      True            1.89
#  1               kg                    2.99     False            2.99
#  3               kg                    3.78     False            1.89
#
#     comparative_unit_discount_price  weight valid_until
#  0                             1.89     1.0  2025-09-08
#  2                             1.89     1.0  2025-09-08
#  1                             2.99     1.0
#  3                             3.78     0.5              ,
#  'Viščiukų blauzdelės':                                                   url  \
#  2   https://barbora.lt/produktai/sviezios-visciuku...
#  11  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  1   https://barbora.lt/produktai/sviezios-visciuku...
#  6   https://www.lastmile.lt/chain/IKI/product/Visc...
#  7   https://www.lastmile.lt/chain/PROMO-CashandCar...
#  3   https://barbora.lt/produktai/sv-visciuku-broil...
#  12  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  0   https://barbora.lt/produktai/visciuku-blauzdel...
#  13  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  4   https://barbora.lt/produktai/svz-broileriu-uza...
#  9   https://www.lastmile.lt/chain/PROMO-CashandCar...
#  8   https://www.lastmile.lt/chain/PROMO-CashandCar...
#  10  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  5   https://www.lastmile.lt/chain/IKI/product/Svie...
#
#                                                  image  \
#  2   https://cdn.barbora.lt/products/87902a59-f768-...
#  11  https://rimibaltic-res.cloudinary.com/image/up...
#  1   https://cdn.barbora.lt/products/9ad84447-5684-...
#  6   https://firebasestorage.googleapis.com/v0/b/la...
#  7   https://storage.googleapis.com/download/storag...
#  3   https://cdn.barbora.lt/products/e9c5406a-9e63-...
#  12  https://rimibaltic-res.cloudinary.com/image/up...
#  0   https://cdn.barbora.lt/products/ca62d055-d964-...
#  13  https://rimibaltic-res.cloudinary.com/image/up...
#  4   https://cdn.barbora.lt/products/d82f0b0e-abb4-...
#  9   https://firebasestorage.googleapis.com/v0/b/la...
#  8   https://firebasestorage.googleapis.com/v0/b/la...
#  10  https://rimibaltic-res.cloudinary.com/image/up...
#  5   https://storage.googleapis.com/download/storag...
#
#                                                  title        date    shop  \
#  2   Šviežios viščiukų broilerių blauzdelės WELL DO...  2025-09-02  MAXIMA
#  11           Viščiukų broilerių blauzdelės RIMI,A,1kg  2025-09-02    RIMI
#  1   Šviežios viščiukų broilerių blauzdelės WELL DO...  2025-09-02  MAXIMA
#  6                Viščiukų broilerių blauzdelės CLEVER  2025-09-02     IKI
#  7         Šaldytos viščiukų broilerių blauzdelės, ROG  2025-09-02     IKI
#  3   Šv. viščiukų broilerių blauzdelės, užauginta b...  2025-09-02  MAXIMA
#  12      Švž.viščiukų broilerių blauzd.be ant.RIMI,1kg  2025-09-02    RIMI
#  0   Viščiukų blauzdelės FIESTA su česnakiniu marin...  2025-09-02  MAXIMA
#  13      Višč. br. blauzdelės be sąn. RIMI, A kl. 500g  2025-09-02    RIMI
#  4   Švž. broilerių, užaugintų be antibiotikų, blau...  2025-09-02  MAXIMA
#  9   Šviežios viščiukų broilerių blauzdelės VILNIAU...  2025-09-02     IKI
#  8   Šviežios viščiukų broilerių blauzdelės VILNIAU...  2025-09-02     IKI
#  10      Broilerių blauzdelės be sąn. be ant. VP, 500g  2025-09-02    RIMI
#  5   Šviežios viščiukų broilerių blauzdelės IKI MĖS...  2025-09-02     IKI
#
#      price comparative_unit  comparative_unit_price  discount  discount_price  \
#  2    3.29               kg                    3.29     False            3.29
#  11   3.89               kg                    3.89     False            3.89
#  1    2.29               kg                    4.58      True            1.99
#  6    3.99               kg                    3.99     False            3.99
#  7    4.47               kg                    4.47     False            4.47
#  3    4.69               kg                    4.69     False            4.69
#  12   4.79               kg                    4.79     False            4.79
#  0    4.49               kg                    5.28     False            4.49
#  13   2.69               kg                    5.38     False            2.69
#  4    2.99               kg                    5.98     False            2.99
#  9    3.59               kg                    7.18      True            3.12
#  8    3.47               kg                    6.94     False            3.47
#  10   3.49               kg                    6.98     False            3.49
#  5    3.59               kg                    7.18     False            3.59
#
#      comparative_unit_discount_price  weight valid_until
#  2                              3.29    1.00
#  11                             3.89    1.00
#  1                              3.98    0.50  2025-09-08
#  6                              3.99    1.02
#  7                              4.47    1.00
#  3                              4.69    1.00
#  12                             4.79    1.00
#  0                              5.28    0.85
#  13                             5.38    0.50
#  4                              5.98    0.50
#  9                              6.24    0.50  2025-09-02
#  8                              6.94    0.50
#  10                             6.98    0.50
#  5                              7.18    0.52              ,
#  'Viščiukų filė':                                                   url  \
#  10  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  1   https://barbora.lt/produktai/lietuviska-sviezi...
#  8   https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  9   https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  2   https://barbora.lt/produktai/sviez-visciuku-br...
#  3   https://www.lastmile.lt/chain/IKI/product/Svie...
#  0   https://barbora.lt/produktai/sviezia-visciuku-...
#  5   https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  4   https://www.lastmile.lt/chain/IKI/product/Svie...
#  6   https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  7   https://www.rimi.lt/e-parduotuve/lt/produktai/...
#
#                                                  image  \
#  10  https://rimibaltic-res.cloudinary.com/image/up...
#  1   https://cdn.barbora.lt/products/e1f4dec3-9e42-...
#  8   https://rimibaltic-res.cloudinary.com/image/up...
#  9   https://rimibaltic-res.cloudinary.com/image/up...
#  2   https://cdn.barbora.lt/products/20d3f54e-0537-...
#  3   https://storage.googleapis.com/download/storag...
#  0   https://cdn.barbora.lt/products/53440a5e-918d-...
#  5   https://rimibaltic-res.cloudinary.com/image/up...
#  4   https://firebasestorage.googleapis.com/v0/b/la...
#  6   https://rimibaltic-res.cloudinary.com/image/up...
#  7   https://rimibaltic-res.cloudinary.com/image/up...
#
#                                                  title        date    shop  \
#  10      Šviež.viščiuko broilerio filė be antib., 500g  2025-09-02    RIMI
#  1   Lietuviška šviežia viščiukų broilerių filė WEL...  2025-09-02  MAXIMA
#  8                Viščiukų krūtinėlių filė RIMI, 500 g  2025-09-02    RIMI
#  9       Švž.viščiukų broilerių filė be  ant.RIMI, 1kg  2025-09-02    RIMI
#  2   Šviežia viščiukų broilerių filė be antibiotikų...  2025-09-02  MAXIMA
#  3   Šviežia viščiukų broilerių vidinė filė IKI MĖS...  2025-09-02     IKI
#  0   Šviežia viščiukų broilerių, užaugintų be antib...  2025-09-02  MAXIMA
#  5       Broilerių filė gabaliukai be antibiotikų,500g  2025-09-02    RIMI
#  4   Šviežia viščiukų broilerių filė užauginta be a...  2025-09-02     IKI
#  6         Broilerių vidinė filė be antibiotikų, 400 g  2025-09-02    RIMI
#  7         Broilerių vidinė filė be antibiotikų, 400 g  2025-09-02    RIMI
#
#      price comparative_unit  comparative_unit_price  discount  discount_price  \
#  10   5.99               kg                   11.98      True            3.49
#  1    3.79               kg                    7.58     False            3.79
#  8    3.99               kg                    7.98     False            3.99
#  9    8.49               kg                    8.49     False            8.49
#  2    4.79               kg                    9.58     False            4.79
#  3    4.99               kg                   12.47      True            3.99
#  0    5.49               kg                   10.98     False            5.49
#  5    5.49               kg                   10.98     False            5.49
#  4    5.99               kg                   11.98     False            5.99
#  6    5.29               kg                   13.22     False            5.29
#  7    5.29               kg                   13.22     False            5.29
#
#      comparative_unit_discount_price  weight valid_until
#  10                             6.98    0.50  2025-09-08
#  1                              7.58    0.50
#  8                              7.98    0.50
#  9                              8.49    1.00
#  2                              9.58    0.50
#  3                              9.97    0.42  2025-09-07
#  0                             10.98    0.50
#  5                             10.98    0.50
#  4                             11.98    0.52
#  6                             13.22    0.40
#  7                             13.22    0.40              ,
#  'Šilauogės':                                                  url  \
#  2  https://barbora.lt/produktai/silauoges-kibirel...
#  4  https://www.lastmile.lt/chain/IKI/product/Sila...
#  3  https://www.lastmile.lt/chain/IKI/product/Sila...
#  5  https://www.lastmile.lt/chain/IKI/product/Sila...
#  0  https://barbora.lt/produktai/lietuviskos-silau...
#  1  https://barbora.lt/produktai/silauoges-well-do...
#
#                                                 image  \
#  2  https://cdn.barbora.lt/products/67c6635a-31d6-...
#  4  https://storage.googleapis.com/download/storag...
#  3  https://storage.googleapis.com/download/storag...
#  5  https://storage.googleapis.com/download/storag...
#  0  https://cdn.barbora.lt/products/cd189527-ee69-...
#  1  https://cdn.barbora.lt/products/941e8068-469a-...
#
#                            title        date    shop  price comparative_unit  \
#  2   Šilauogės kibirėlyje, 400 g  2025-09-02  MAXIMA   6.99               kg
#  4             Šilauogės, 500 g.  2025-09-02     IKI   6.99               kg
#  3              Šilauogės, 125 g  2025-09-02     IKI   1.99               kg
#  5              Šilauogės, 250 g  2025-09-02     IKI   3.99               kg
#  0  Lietuviškos šilauogės, 500 g  2025-09-02  MAXIMA   5.99               kg
#  1    Šilauogės WELL DONE, 125 g  2025-09-02  MAXIMA   2.49               kg
#
#     comparative_unit_price  discount  discount_price  \
#  2                   17.48      True            3.89
#  4                   13.98      True            4.89
#  3                   15.92      True            1.39
#  5                   15.96      True            2.79
#  0                   11.98     False            5.99
#  1                   19.92     False            2.49
#
#     comparative_unit_discount_price  weight valid_until
#  2                             9.73   0.400  2025-09-08
#  4                             9.78   0.550  2025-09-07
#  3                            11.12   0.130  2025-09-07
#  5                            11.16   0.260  2025-09-07
#  0                            11.98   0.500
#  1                            19.92   0.125              ,
#  'Špinatai':                                                  url  \
#  1  https://barbora.lt/produktai/mazieji-spinatai-...
#  3  https://www.rimi.lt/e-parduotuve/lt/produktai/...
#  2  https://www.lastmile.lt/chain/IKI/product/Mazi...
#  0  https://barbora.lt/produktai/spinatai-well-don...
#
#                                                 image  \
#  1  https://cdn.barbora.lt/products/b30e1179-cef4-...
#  3  https://rimibaltic-res.cloudinary.com/image/up...
#  2  https://storage.googleapis.com/download/storag...
#  0  https://cdn.barbora.lt/products/c6fa49e6-cf09-...
#
#                                 title        date    shop  price  \
#  1  Mažieji špinatai WELL DONE, 200 g  2025-09-02  MAXIMA   1.79
#  3                    Špinatai, 200 g  2025-09-02    RIMI   1.89
#  2        Mažieji špinatai IKI, 100 g  2025-09-02     IKI   1.49
#  0          Špinatai WELL DONE, 100 g  2025-09-02  MAXIMA   1.29
#
#    comparative_unit  comparative_unit_price  discount  discount_price  \
#  1               kg                    8.95     False            1.79
#  3               kg                    9.45     False            1.89
#  2               kg                   14.90      True            0.99
#  0               kg                   12.90     False            1.29
#
#     comparative_unit_discount_price  weight valid_until
#  1                             8.95    0.20
#  3                             9.45    0.20
#  2                             9.90    0.11  2025-09-07
#  0                            12.90    0.10              }

# %% [markdown]
# ## Collect your cart
# ### Review what's on stock (in jupyter view)
# Record initial preview of `hunt list`

# %%
#items = ('Mangų kisielius', 'Druska', 'Burokėliai', 'Obuolių pudingas')
catalogue = collect_catalogue(items=items_hunt, offline=True)
preview_mds = []
for item in catalogue:
    df = get_view(catalogue[item])
    preview_mds.append(f'## {item}\n{df.to_markdown()}')
preview = '\n'.join(preview_mds)
with open('hunt.md', 'w', encoding='utf-8') as f:
    f.write(preview)

# %% [markdown]
# * Run [hunt_it.ipynb](hunt_it.ipynb) to preview recording of `hunt list` ready to push on GitHub

# %%
catalogue.keys()
# Out:
# dict_keys(['Avietės', 'Aviečių uogienė', 'Avižų gėrimas', 'Bananai', 'Bulvės', 'Burokėliai', 'Džiovinti krapai', 'Grietinė', 'Kiaušiniai', 'Kokosų gėrimas', 'Morkos', 'Paprikos', 'Pomidorų pasta', 'Ridikėliai', 'Skumbrė', 'Sviestas', 'Svogūnų laiškai', 'Viščiukų blauzdelės', 'Viščiukų filė', 'Šilauogės', 'Špinatai'])

# %% [markdown]
# ### Collect what to look for in a shop
# Choose from `hunt list` what you want to collect

# %%
import dash
from dash import Dash, dash_table, html, Output, Input, callback
from itertools import chain

app = Dash()
items = items_hunt
def to_table(df, item):
    columns = []
    for i, name in enumerate(df.columns):
        if name in ('title', 'image'):
            columns.append({"name": name, "id": name, 'presentation': 'markdown'})
        else:
            columns.append({"name": name, "id": name, 'presentation': 'markdown'})
    return dash_table.DataTable(data = df.to_dict('records'), row_selectable="multi", selected_rows=[],
                                columns = columns, id=f'table-{item}', 
                                markdown_options={"html": True},
                                fill_width=False)


app.layout = html.Div([*list(chain(*[[html.Td(item), to_table(get_view(catalogue[item]), item)] for item in items])),
                       html.Div(id='selected-rows-output')])

#app.layout = html.Div([to_table(df), html.Div(id='selected-rows-output')])

# Callback to handle row selection
@app.callback(
    Output('selected-rows-output', 'children'),
    [Input(f'table-{item}', 'selected_rows') for item in items]
)
def update_output(*selected_rows):    
    # Retrieve the IDs of the selected rows
    selection = {items[i]: val for i, val in enumerate(selected_rows)}
    df = pd.concat([catalogue[item].iloc[idx] for item, idx in selection.items()])
    df.to_csv('cart.csv', index=False)
    return str(selection)
    
if __name__ == '__main__':
    app.run(debug=True, jupyter_mode="external")
# Out:
# Dash app running on http://127.0.0.1:8050/

# %% [markdown]
# Record your choice in a `collect list`

# %%
df = pd.read_csv('cart.csv')
sorter = {'by':['shop'], 'ascending': [True]}
df = df.sort_values(**sorter)
preview = get_view(df).to_markdown()
with open('collect.md', 'w', encoding='utf-8') as f:
    f.write(preview)

# %% [markdown]
# * Run [collect_it.ipynb](collect_it.ipynb) to preview recording of `collect list` ready to push on GitHub

# %% [markdown]
# ### Push both `hunt list` and `collect list`
# You'll need them in shop you visit

# %%
from items import candidates
from shopscraping import scrape, get_view
from IPython.display import Markdown, display
import os
import pandas as pd
from recipe_formatter import normalise_recipe, parse_recipe

def investigate_recipe(recipe_data, offline=True):
    recipe_df = normalise_recipe(recipe_data)
    #display(recipe_df)
    catalogue = collect_catalogue(items=recipe_df['name'], offline=offline)
    if catalogue:
        prices, discount_prices, discounts = [], [], []
        for weight, unit, title in recipe_df.values:
            price = None
            discount_price = None
            discount = None
            
            if title not in catalogue:
                pass
                #print('Please update candidate file with:', title)

            elif unit is None:
                pass
                
            elif not(all(catalogue[title]['comparative_unit'] == unit)):
                print(f'Inconsistent weight units: [{title}] is in {unit} but catalogue contains:', 
                      catalogue[title]['comparative_unit'].tolist())
            else:
                #display_items(catalogue[title])
                price = weight * catalogue[title]['comparative_unit_price'].min()
                discount_price = weight * catalogue[title]['comparative_unit_discount_price'].min()
                discount = price - discount_price
            prices.append(price)
            discount_prices.append(discount_price)
            discounts.append(discount)
            
        recipe_df['price'] = [round(n, 2) if n else n for n in prices]
        recipe_df['discount_price'] = [round(n, 2) if n else n for n in discount_prices]
        recipe_df['discount'] = [round(n, 2) if n else n for n in discounts]
        return recipe_df
